# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, root_mean_squared_error, classification_report, confusion_matrix, accuracy_score
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df=pd.read_csv("Agrodatalab.csv")

# 1.2. Para evitar error, conviente quitar espacios en blaco de los nombre de las columnas del dataset
df.columns= df.columns.str.strip()

# 2. Muestra el número total de filas y columnas.

print(f"Dimensiones del dataset:{df.shape}")
print("\n Primeros registros:")
df.head()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
